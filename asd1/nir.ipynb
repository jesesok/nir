# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import os
path = 'C:/Users/ThinkPad/Desktop/path'
import pandas as pd

# %%
img = cv2.imread('C:/work/defects_pic/figs_bzt/477.png')
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
img_gs = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
kernel1 = np.array([[-1, -2, -1], [0, 0, 0], [1, 2, 1]])
kernel2 = np.transpose([[-1, -2, -1], [0, 0, 0], [1, 2, 1]])
t1 = cv2.filter2D(img_gs, -1, kernel1)
t2 = cv2.filter2D(img_gs, -1, kernel2)

# %%
plt.imshow(img)

# %%
plt.imshow(img_gs,cmap='gray')

# %%
plt.imshow(t1,cmap='gray')

# %%
plt.imshow(t2,cmap='gray')

# %%
cv2.imwrite(os.path.join(path , '1.jpg'), t1)
cv2.imwrite(os.path.join(path , '2.jpg'), t2)
cv2.imwrite(os.path.join(path , '3.jpg'), img_gs)
# Out:
# True

# %%
plt.imshow(img[395:1034,586:1602,])

# %%
brightImg = (img[78:249,1122:1528,])
nonBrightImg = (img[582:881,126:369,])
plt.imshow(brightImg)

# %%
plt.imshow(nonBrightImg)

# %%
np.median(img)
# Out:
# 110.0

# %%
np.median(brightImg)
# Out:
# 209.0

# %%
np.median(nonBrightImg)
# Out:
# 93.0

# %%
for i in range(0,1080,):
    for j in range(0,1920,):
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-a6755e51850b> in <module>
#       1 for i in range(0,1080,):
#       2     for j in range(0,1920,):
# ----> 3         plt.subplots.imshow(img[i:i+50,j:j+50,])
#       4
#
# AttributeError: 'function' object has no attribute 'imshow'

# %%
def l2_dist(a, b):
    result = ((a - b) * (a - b)).sum()
    result = result ** 0.5
    return result
