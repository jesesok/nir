# %%
import  pandas as pd
import plotly

# %%
df = pd.read_csv('Wine (3).txt', sep='\t')
df.head(5)
# Out:
#    Input1  Input2  Input3  Input4  Input5  Input6  Input7  Input8  Input9  \
# 0   14.23    1.71    2.43    15.6     127    2.80    3.06    0.28    2.29
# 1   13.20    1.78    2.14    11.2     100    2.65    2.76    0.26    1.28
# 2   13.16    2.36    2.67    18.6     101    2.80    3.24    0.30    2.81
# 3   14.37    1.95    2.50    16.8     113    3.85    3.49    0.24    2.18
# 4   13.24    2.59    2.87    21.0     118    2.80    2.69    0.39    1.82
#
#    Input10  Input11  Input12  Input13  Desired1(3)
# 0     5.64     1.04     3.92     1065            0
# 1     4.38     1.05     3.40     1050            0
# 2     5.68     1.03     3.17     1185            0
# 3     7.80     0.86     3.45     1480            0
# 4     4.32     1.04     2.93      735            0

# %%
df.hist(figsize=(15,15))
# Out:
# array([[<AxesSubplot:title={'center':'Input1'}>,
#         <AxesSubplot:title={'center':'Input2'}>,
#         <AxesSubplot:title={'center':'Input3'}>,
#         <AxesSubplot:title={'center':'Input4'}>],
#        [<AxesSubplot:title={'center':'Input5'}>,
#         <AxesSubplot:title={'center':'Input6'}>,
#         <AxesSubplot:title={'center':'Input7'}>,
#         <AxesSubplot:title={'center':'Input8'}>],
#        [<AxesSubplot:title={'center':'Input9'}>,
#         <AxesSubplot:title={'center':'Input10'}>,
#         <AxesSubplot:title={'center':'Input11'}>,
#         <AxesSubplot:title={'center':'Input12'}>],
#        [<AxesSubplot:title={'center':'Input13'}>,
#         <AxesSubplot:title={'center':'Desired1(3)'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)
